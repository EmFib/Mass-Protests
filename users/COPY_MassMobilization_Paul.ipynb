# %%
import pandas as pd

# %%
mass = pd.read_csv('../source/mmALL_073120_csv.csv')
mass.head(2)
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
#
#    startday  startmonth  startyear  ...  protesterdemand4  stateresponse1  \
# 0      15.0         1.0     1990.0  ...               NaN          ignore
# 1      25.0         6.0     1990.0  ...               NaN          ignore
#
#    stateresponse2  stateresponse3 stateresponse4 stateresponse5  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
#
#   stateresponse6 stateresponse7  \
# 0            NaN            NaN
# 1            NaN            NaN
#
#                                              sources  \
# 0  1. great canadian train journeys into history;...
# 1  1. autonomy s cry revived in quebec the new yo...
#
#                                                notes
# ...

# %%
prosperity_df = pd.read_excel('../data/Prosperity_Index.xlsx', sheet_name=1)

# %%
prosperity_df.head()
# Out:
#                 country  isonum isocode  rank_PI2007  rank_PI2008  \
# 0           Afghanistan       4     AFG          148          147
# 1                Angola      24     AGO          135          132
# 2               Albania       8     ALB           83           74
# 3  United Arab Emirates     784     ARE           43           42
# 4             Argentina      32     ARG           59           61
#
#    rank_PI2009  rank_PI2010  rank_PI2011  rank_PI2012  rank_PI2013  ...  \
# 0          147          147          149          149          147  ...
# 1          134          136          139          141          141  ...
# 2           70           73           71           74           80  ...
# 3           42           41           42           42           41  ...
# 4           53           47           45           46           46  ...
#
#       PI2007     PI2008     PI2009     PI2010     PI2011     PI2012  \
# ...

# %%
mass.iloc[1:12,1:12]
# Out:
#    country  ccode  year         region  protest  protestnumber  startday  \
# 1   Canada     20  1990  North America        1              2      25.0
# 2   Canada     20  1990  North America        1              3       1.0
# 3   Canada     20  1990  North America        1              4      12.0
# 4   Canada     20  1990  North America        1              5      14.0
# 5   Canada     20  1990  North America        1              6      19.0
# 6   Canada     20  1991  North America        1              1      10.0
# 7   Canada     20  1991  North America        1              2      28.0
# 8   Canada     20  1992  North America        1              1       4.0
# 9   Canada     20  1993  North America        1              1      16.0
# 10  Canada     20  1993  North America        1              2       1.0
# 11  Canada     20  1994  North America        1              1       1.0
#
#     startmonth  startyear  endday  endmonth
# 1          6.0     1990.0    25.0       6.0
# ...

# %%
#mass.groupby(['stateresponse1','stateresponse2','stateresponse3']).count()

# %%
set(list(mass[mass['protestnumber']>50]['country']))
# Out:
# {'Algeria',
#  'Bangladesh',
#  'China',
#  'Cuba',
#  'Germany',
#  'Ireland',
#  'Kenya',
#  'Lebanon',
#  'Nigeria',
#  'Romania',
#  'Ukraine',
#  'Yemen'}

# %%
countries_df =pd.DataFrame(sorted(list(mass['country'].value_counts().index)  ) , columns=['country'])
print (f'There are {countries_df.shape[0]} countries.')
countries_df.head()
# Out:
# There are 166 countries.
#        country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3       Angola
# 4    Argentina

# %%
prosperity_df.head()
# Out:
#                 country  isonum isocode  rank_PI2007  rank_PI2008  \
# 0           Afghanistan       4     AFG          148          147
# 1                Angola      24     AGO          135          132
# 2               Albania       8     ALB           83           74
# 3  United Arab Emirates     784     ARE           43           42
# 4             Argentina      32     ARG           59           61
#
#    rank_PI2009  rank_PI2010  rank_PI2011  rank_PI2012  rank_PI2013  ...  \
# 0          147          147          149          149          147  ...
# 1          134          136          139          141          141  ...
# 2           70           73           71           74           80  ...
# 3           42           41           42           42           41  ...
# 4           53           47           45           46           46  ...
#
#       PI2007     PI2008     PI2009     PI2010     PI2011     PI2012  \
# ...

# %%
country_PI_df = prosperity_df[['country','PI2016']].copy()

# %%
country_PI_df.head()
# Out:
#                 country     PI2016
# 0           Afghanistan  37.432201
# 1                Angola  42.886642
# 2               Albania  58.033268
# 3  United Arab Emirates  64.007759
# 4             Argentina  61.759857

# %%
mass = mass.merge(country_PI_df, how='left', 
                        left_on='country', 
                        right_on='country')

# %%
mass.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  ...   stateresponse1  stateresponse2  \
# 0      15.0         1.0     1990.0  ...           ignore             NaN
# 1      25.0         6.0     1990.0  ...           ignore             NaN
# 2       1.0         7.0     1990.0  ...           ignore             NaN
# 3      12.0         7.0     1990.0  ...     accomodation             NaN
# 4      14.0         8.0     1990.0  ...  crowd dispersal         arrests
#
#    stateresponse3  stateresponse4 stateresponse5 stateresponse6  \
# ...

# %%
prosperity_countries = sorted(list(prosperity_df['country']))
mass_countries = sorted(list(mass['country'].value_counts().index))

mass_not_prosperity = []
prosperity_not_in_mass = []

for country in mass_countries:
    if country not in prosperity_countries:
        mass_not_prosperity.append(country)
        
for country in prosperity_countries:
    if country not in mass_countries:
        prosperity_not_in_mass.append(country)
        
mass_not_prosperity
# Out:
# ['Bhutan',
#  'Bosnia',
#  'Cape Verde',
#  'Congo Brazzaville',
#  'Congo Kinshasa',
#  'Cuba',
#  'Czechoslovakia',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Gambia',
#  'Germany East',
#  'Germany West',
#  'Guinea-Bissau',
#  'Haiti',
#  'Kosovo',
#  'Myanmar',
#  'North Korea',
#  'Papua New Guinea',
#  'Serbia and Montenegro',
#  'Slovak Republic',
#  'Somalia',
#  'South Sudan',
#  'Syria',
#  'Taiwan',
#  'Timor Leste',
#  'Turkmenistan',
#  'USSR',
#  'United Arab Emirate',
#  'Uzbekistan',
#  'Yugoslavia']

# %%
prosperity_not_in_mass
# Out:
# ['Australia',
#  'Belize',
#  'Congo',
#  'Democratic Republic of Congo',
#  'Hong Kong',
#  'Iceland',
#  'Israel',
#  'Malta',
#  'New Zealand',
#  'Slovakia',
#  'Trinidad and Tobago',
#  'United Arab Emirates',
#  'United States']

# %%
mass[mass['country']=='Bhutan']
# Out:
#                id country  ccode  year region  protest  protestnumber  \
# 15319  7601990001  Bhutan    760  1990   Asia        1              1
# 15320  7601991000  Bhutan    760  1991   Asia        0              0
# 15321  7601992000  Bhutan    760  1992   Asia        0              0
# 15322  7601993000  Bhutan    760  1993   Asia        0              0
# 15323  7601994000  Bhutan    760  1994   Asia        0              0
# 15324  7601995000  Bhutan    760  1995   Asia        0              0
# 15325  7601996000  Bhutan    760  1996   Asia        0              0
# 15326  7601997000  Bhutan    760  1997   Asia        0              0
# 15327  7601998000  Bhutan    760  1998   Asia        0              0
# 15328  7601999001  Bhutan    760  1999   Asia        1              1
# 15329  7602000000  Bhutan    760  2000   Asia        0              0
# 15330  7602001000  Bhutan    760  2001   Asia        0              0
# ...

# %%
prosperity_df[prosperity_df['country']=='United States']
# Out:
#            country  isonum isocode  rank_PI2007  rank_PI2008  rank_PI2009  \
# 142  United States     840     USA           16           16           16
#
#      rank_PI2010  rank_PI2011  rank_PI2012  rank_PI2013  ...     PI2007  \
# 142           17           18           17           16  ...  73.442772
#
#         PI2008     PI2009     PI2010     PI2011     PI2012     PI2013  \
# 142  74.141075  73.270508  73.079292  72.672562  72.637436  72.975677
#
#         PI2014     PI2015     PI2016
# 142  73.342461  73.570953  73.505516
#
# [1 rows x 23 columns]
