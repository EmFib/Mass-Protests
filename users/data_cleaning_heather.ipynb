# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mass = pd.read_csv('mmALL_073120_csv.csv')

# %%
mass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17145 entries, 0 to 17144
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     17145 non-null  int64
#  1   country                17145 non-null  object
#  2   ccode                  17145 non-null  int64
#  3   year                   17145 non-null  int64
#  4   region                 17145 non-null  object
#  5   protest                17145 non-null  int64
#  6   protestnumber          17145 non-null  int64
#  7   startday               15239 non-null  float64
#  8   startmonth             15239 non-null  float64
#  9   startyear              15239 non-null  float64
#  10  endday                 15239 non-null  float64
#  11  endmonth               15239 non-null  float64
#  12  endyear                15239 non-null  float64
#  13  protesterviolence      15758 non-null  float64
# ...

# %%
mass.drop(['region', 'startmonth', 'endmonth', 'ccode', 'startday', 'endday', 'startyear', 'endyear', 'id', 'location'], axis=1).head(30)
# Out:
#    country  year  protest  protestnumber  protesterviolence  \
# 0   Canada  1990        1              1                0.0
# 1   Canada  1990        1              2                0.0
# 2   Canada  1990        1              3                0.0
# 3   Canada  1990        1              4                1.0
# 4   Canada  1990        1              5                1.0
# 5   Canada  1990        1              6                0.0
# 6   Canada  1991        1              1                0.0
# 7   Canada  1991        1              2                0.0
# 8   Canada  1992        1              1                1.0
# 9   Canada  1993        1              1                0.0
# 10  Canada  1993        1              2                0.0
# 11  Canada  1994        1              1                0.0
# 12  Canada  1994        1              2                0.0
# 13  Canada  1995        1              1                0.0
# 14  Canada  1995        1              2                1.0
# ...

# %%
mm['participants_category'].value_counts().tail(50)
# Out:
# 100-999       3204
# 50-99         2508
# 2000-4999     1580
# >10000        1470
# 5000-10000     642
# 1000-1999      483
# Name: participants_category, dtype: int64

# %%
mm_nonprotests = mm[mm['protest'] == 0]

# %%
mm_nonprotests['country'].value_counts().head(50)
# Out:
# Qatar                  30
# Cape Verde             30
# Luxembourg             29
# Laos                   29
# Bhutan                 29
# Eritrea                28
# United Arab Emirate    28
# Equatorial Guinea      27
# Turkmenistan           27
# Oman                   27
# Norway                 26
# Rwanda                 26
# Switzerland            25
# Singapore              24
# North Korea            24
# Finland                24
# Libya                  23
# Denmark                23
# Cuba                   23
# Chad                   22
# Saudi Arabia           22
# Mauritius              22
# Djibouti               22
# Netherlands            22
# Gambia                 22
# Syria                  22
# Sweden                 21
# Somalia                20
# Sudan                  20
# Tajikistan             19
# Slovenia               19
# Botswana               19
# Tunisia                19
# Uzbekistan             19
# Jordan                 19
# ...
